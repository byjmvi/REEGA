# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python

# %%
import pypsa

# %%
n.plot(
    bus_sizes=0.1,
    line_widths=0.5,
    flow=None
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 n.plot(
#       2     bus_sizes=0.1,
#       3     line_widths=0.5,
#       4     flow=None
#
# File ~/Kolleg/.venv/lib/python3.14/site-packages/pypsa/plot/accessor.py:32, in PlotAccessor.__call__(self, *args, **kwargs)
#      29 @functools.wraps(plot)
#      30 def __call__(self, *args: Any, **kwargs: Any) -> Any:
#      31     """Alias for [pypsa.Network.plot.map][pypsa.plot.PlotAccessor.map]."""
# ---> 32     return plot(self._n, *args, **kwargs)
#
# File ~/Kolleg/.venv/lib/python3.14/site-packages/pypsa/common.py:548, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     543 @functools.wraps(f)
#     544 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     545     rename_deprecated_kwargs(
#     546         f.__name__, kwargs, aliases, deprecated_in, removed_in
#     547     )
# --> 548     return f(*args, **kwargs)
#
# File ~/Kolleg/.venv/lib/python3.14/site-packages/pypsa/plot/maps/static.py:1310, in plot(n, ax, layouter, boundaries, margin, projection, geomap, geomap_resolution, geomap_color, title, jitter, **kwargs)
#    1300 # setup plotter
#    1301 plotter = MapPlotter(
#    1302     n,
#    1303     layouter,
#    (...)   1307     jitter=jitter,
#    1308 )
# -> 1310 return plotter.draw_map(
#    1311     ax,
#    1312     projection=projection,
#    1313     geomap=geomap,
#    1314     geomap_resolution=geomap_resolution,
#    1315     geomap_color=geomap_color,
#    1316     title=title,
#    1317     **kwargs,
#    1318 )
#
# File ~/Kolleg/.venv/lib/python3.14/site-packages/pypsa/common.py:548, in deprecated_kwargs.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     543 @functools.wraps(f)
#     544 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     545     rename_deprecated_kwargs(
#     546         f.__name__, kwargs, aliases, deprecated_in, removed_in
#     547     )
# --> 548     return f(*args, **kwargs)
#
# TypeError: MapPlotter.draw_map() got an unexpected keyword argument 'flow'

# %%
n.buses.shape
n.generators.shape
n.loads.shape
n.lines.shape
n.storage_units.shape
# Out:
# (5, 40)

# %%
n.optimize()
n.generators_t.p.plot()
n.plot()
# Out:
# /tmp/ipykernel_8723/1737403122.py:1: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize()
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io: Writing time: 0.23s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 570 primals, 1203 duals
# Objective: 5.00e+07
# Solver: highs
# Runtime: 0.03s
# MIP gap: inf
# Dual bound: 0.00e+00
# Solver model: available
# Solver message: Optimal
# Running HiGHS 1.15.1 (git hash: 04024d7): Copyright (c) 2026 under MIT licence terms
# Includes third-party software components, see THIRD_PARTY_NOTICES.md for full details
# LP linopy-problem-jrix0g_0 has 1196 rows; 570 cols; 2440 nonzeros
# Coefficient ranges:
#   Matrix  [3e-02, 3e+01]
#   Cost    [2e-01, 2e+04]
#   Bound   [1e+08, 1e+08]
#   RHS     [2e+01, 2e+06]
# WARNING: Problem has some excessively large column bounds
# WARNING: Problem has some excessively large row bounds
# WARNING:    Consider scaling the    bounds by 1e-3, or setting the user_bound_scale option to -7
# Presolving model
# 609 rows, 560 cols, 1824 nonzeros 0s
# Dependent equations search running on 105 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.00s (limit = 1000.00s)
# 567 rows, 518 cols, 1789 nonzeros 0s
# Presolve reductions: rows 567(-629); columns 518(-52); nonzeros 1789(-651)
# Solving the presolved LP
# Using dual simplex solver
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.1140085702e-01 Ph1: 145(216531); Du: 11(0.111401) 0.0s
#         376     5.0007306001e+07 Pr: 0(0); Du: 0(2.33487e-14) 0.0s
#         376     5.0007306001e+07 Pr: 0(0); Du: 0(2.33487e-14) 0.0s
#
# Performed postsolve
# Solving the original LP from the solution after postsolve
#
# Model name          : linopy-problem-jrix0g_0
# Model status        : Optimal
# Simplex   iterations: 376
# Objective value     :  5.0007306001e+07
# P-D objective error :  2.2348476008e-16
# HiGHS run time      :          0.03
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, Link-ext-p-lower, Link-ext-p-upper, Store-ext-e-lower, Store-ext-e-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, Kirchhoff-Voltage-Law, StorageUnit-energy_balance, Store-energy_balance were not assigned to the network.
# WARNING:pypsa.plot.maps.static:Cartopy is not available. Falling back to non-geographic plotting.
# WARNING:pypsa.plot.maps.static:Cartopy needs to be installed to use `geomap=True`.
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x7f5f332a0910>},
#  'branches': {'Link': <matplotlib.collections.LineCollection at 0x7f5f332a0cd0>,
#   'Line': <matplotlib.collections.LineCollection at 0x7f5f332a0e10>},
#  'flows': {}}

# %%
n = pypsa.Network(
    "solved_2050.nc"
)

print(n)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v1.2.4 while current version is v1.3.0. Read the release notes at `https://go.pypsa.org/release-notes` to prepare your network for import.
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores, sub_networks
# PyPSA Network 'Unnamed Network'

# %%
# create a new network
n = pypsa.Network()
n.add("Bus", "mybus")
n.add("Load", "myload", bus="mybus", p_set=100)
n.add("Generator", "mygen", bus="mybus", p_nom=100, marginal_cost=20)

# load an example network
n = pypsa.examples.ac_dc_meshed()

# run the optimisation
n.optimize()

# plot results
n.generators_t.p.plot()
n.plot()

# get statistics
n.statistics()
n.statistics.energy_balance()
# Out:
# /home/jasper/Kolleg/.venv/lib/python3.14/site-packages/pypsa/network/io.py:2082: FutureWarning: pandas infers the `str` dtype for string data since its version 3.0. PyPSA still converts it back to numpy object dtype on import, but will keep it from PyPSA 2.0 on. Set `pypsa.options.api.legacy_string_dtype` explicitly to suppress this warning.
#   new_static = _coerce_string_dtypes(new_static)
# INFO:pypsa.network.io:Imported network 'AC-DC-Meshed' has buses, carriers, generators, global_constraints, lines, links, loads
# /tmp/ipykernel_8723/2990568795.py:11: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize()
# WARNING:pypsa.consistency:The following lines have zero x, which could break the linear load flow:
# Index(['2', '3', '4'], dtype='object', name='name')
# WARNING:pypsa.consistency:The following lines have zero r, which could break the linear load flow:
# Index(['0', '1', '5', '6'], dtype='object', name='name')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io: Writing time: 0.25s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 188 primals, 468 duals
# Objective: -3.47e+06
# Solver: highs
# Runtime: 0.02s
# MIP gap: inf
# Dual bound: 0.00e+00
# Solver model: available
# Solver message: Optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-ext-s-lower, Line-ext-s-upper, Link-ext-p-lower, Link-ext-p-upper, Kirchhoff-Voltage-Law were not assigned to the network.
# Running HiGHS 1.15.1 (git hash: 04024d7): Copyright (c) 2026 under MIT licence terms
# Includes third-party software components, see THIRD_PARTY_NOTICES.md for full details
# LP linopy-problem-1av52nwe has 468 rows; 188 cols; 1007 nonzeros
# Coefficient ranges:
#   Matrix  [1e-02, 1e+00]
#   Cost    [9e-03, 3e+03]
#   Bound   [2e+07, 2e+07]
#   RHS     [9e-01, 1e+03]
# WARNING: Problem has some excessively large column bounds
# WARNING:    Consider scaling the    bounds by 1e-2, or setting the user_bound_scale option to -5
# Presolving model
# 391 rows, 187 cols, 930 nonzeros 0s
# 306 rows, 102 cols, 1040 nonzeros 0s
# Dependent equations search running on 25 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.00s (limit = 1000.00s)
# 306 rows, 102 cols, 1040 nonzeros 0s
# Presolve reductions: rows 306(-162); columns 102(-86); nonzeros 1040(+33)
# Solving the presolved LP
# Using dual simplex solver
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.1204525348e+07 Pr: 96(82266); Du: 0(4.26048e-11) 0.0s
#         108    -3.4742560405e+06 Pr: 0(0) 0.0s
#
# Performed postsolve
# Solving the original LP from the solution after postsolve
#
# Model name          : linopy-problem-1av52nwe
# Model status        : Optimal
# Simplex   iterations: 108
# Objective value     : -3.4742560405e+06
# P-D objective error :  1.3403192363e-16
# HiGHS run time      :          0.02
# WARNING:pypsa.plot.maps.static:Cartopy is not available. Falling back to non-geographic plotting.
# WARNING:pypsa.plot.maps.static:Cartopy needs to be installed to use `geomap=True`.
# component  carrier  bus_carrier
# Generator  gas      AC              1465.27439
#            wind     AC             31082.35370
# Load       load     AC            -32547.62808
# dtype: float64
